# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Matplotlib Basics")
# Out:
# Matplotlib Basics

# %%
x = np.linspace(0,5,11)
x
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("HELLO")
plt.xlabel("X AXIS")
plt.ylabel("Y AXIS")
# Out:
# Text(0, 0.5, 'Y AXIS')

# %%
print("Subplots in Matplotlib")
# Out:
# Subplots in Matplotlib

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
print("Object Oriented Way")
# Out:
# Object Oriented Way

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuble of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(20,8),dpi=100)
axis1 = fig.add_axes([0.1,0.1,.4,.8])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y)

# %%
print("Types of Plots")
# Out:
# Types of Plots

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([11., 10., 10., 10., 11.,  9., 11.,  9., 12.,  7.]),
#  array([  5. , 104.4, 203.8, 303.2, 402.6, 502. , 601.4, 700.8, 800.2,
#         899.6, 999. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2922bfee990>,
#   <matplotlib.lines.Line2D at 0x2922bfeead0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2922bfeec10>,
#   <matplotlib.lines.Line2D at 0x2922bfeed50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2922bfee850>],
#  'medians': [<matplotlib.lines.Line2D at 0x2922bfeee90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2922bfeefd0>],
#  'means': []}

# %% [markdown]
# Saving Plots

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working with Images

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("Maharana Pratap Singh.jpeg")

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(746.5), np.float64(999.5), np.float64(-0.5))

# %% [markdown]
# OPTIONAL DESIGING

# %%
plt.plot(x,y, color='red')

# %%
xaxis = np.linspace(0,5,11)

# %%
import numpy as np
import matplotlib.pyplot as plt

xaxis = np.linspace(0, 5, 11)

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis*1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis*2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis*3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis*4, color="red", linewidth=2.00)

ax.plot(xaxis, xaxis*5, color="green", lw=3, linestyle='--')
ax.plot(xaxis, xaxis*6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis*7, color="green", lw=3, ls=':')

line, = ax.plot(xaxis, xaxis*8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50])

ax.plot(xaxis, xaxis*9, color="blue", lw=3, ls='--', marker='+')
ax.plot(xaxis, xaxis*10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis*11, color="blue", lw=3, ls='--', marker='s')
ax.plot(xaxis, xaxis*12, color="blue", lw=3, ls='--', marker='1')

ax.plot(xaxis, xaxis*13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis*14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis*15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")

ax.plot(
    xaxis, xaxis*16, color="purple", lw=1, ls='-',
    marker='s', markersize=8,
    markerfacecolor="yellow",
    markeredgewidth=3,
    markeredgecolor="green"
)

plt.show()
